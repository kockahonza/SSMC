# %%
using Revise
using SSMCMain, SSMCMain.ModifiedMiCRM, SSMCMain.SpaceMMiCRM, MLSolver
# Out:
# Precompiling packages...
#   10476.3 ms  ✓ SSMCMain
#   1 dependency successfully precompiled in 13 seconds. 475 already precompiled.

# %%
using CairoMakie, ProgressLogging
using Base.Threads
using BenchmarkTools
using JLD2, Geppetto

# %% [markdown]
# # Steven's layer model

# %% [markdown]
# ## Basic no space solve

# %% [markdown]
# - 4 strains with 7 resources
# - I'll make first the "glucose" which is all leaked

# %%
l = fill(0., 4, 7)
c = fill(0., 4, 7)
c[:, 1] .= 2. # they all eat glucose
l[:, 1] .= 1. # and they leak all of it

D = fill(0., 4, 7, 7)
# 1-2 cross feeding
D[1, 2, 1] = 0.8
c[2, 2] = 2.
D[2, 3, 1] = 1.
c[1, 3] = 2.

# 3-4 cross feeding
D[3, 4, 1] = 0.8
c[4, 4] = 2.
D[4, 5, 1] = 1.
c[3, 5] = 2.

# 1-3 cross feeding
D[1, 6, 1] = 0.2
c[3, 6] = 1.
D[3, 7, 1] = 0.2
c[1, 7] = 1.

# display(l)
# display(c)
# display(D)
p = make_mmicrm_smart(4, 7, 200;
    D, l, c,
    K=[5., 0., 0., 0., 0., 0., 0.],
    r=fill(0.3, 7),
    m=fill(0.7, 4),
    u0=:onlyN,
    u0rand=0.
)
s = solve(p)
display(plot_mmicrm_sol(s))
s[end]
#param_summary(p.p)
# check_mmicrmparams(p.p)
# Out:
# 11-element Vector{Float64}:
#  1.7579235174143404
#  1.4024255637823093
#  1.7579235174143404
#  1.4024255637823093
#  0.38635707264450014
#  0.3499999999783131
#  0.28399305866441665
#  0.3499999999783131
#  0.28399305866441665
#  0.13201388260393268
#  0.13201388260393268

# %% [markdown]
# #### Steady state solving

# %%
symsol = symbolic_solve_ode_ml(p)
# Out:
# ┌ Warning: Solve::ratnz: Solve was unable to solve the system with inexact coefficients.
# │     The answer was obtained by solving a corresponding exact system and
# │     numericizing the result.
# └ @ MathLink ~/.julia/packages/MathLink/S39uA/src/eval.jl:16
# 65-element Vector{Vector{Pair{Symbolics.Num, Complex{Symbolics.Num}}}}:
#  [u1 => -0.0025988975085542093, u2 => 0.023669403378296625, u3 => -0.25658264915542583, u4 => 0.0, u5 => -29.235613843145874, u6 => 0.35, u7 => -4.694602179828955, u8 => 40.00720666431685, u9 => 0.0, u10 => 0.7, u11 => 10.08920435965791]
#  [u1 => -0.25658264915542583, u2 => 0.0, u3 => -0.0025988975085542093, u4 => 0.023669403378296625, u5 => -29.235613843145874, u6 => 40.00720666431685, u7 => 0.0, u8 => 0.35, u9 => -4.694602179828955, u10 => 10.08920435965791, u11 => 0.7]
#  [u1 => -0.15, u2 => 0.0, u3 => -0.15, u4 => 0.0, u5 => -16.666666666666668, u6 => 13.333333333333334, u7 => -2.9833333333333334, u8 => 13.333333333333334, u9 => -2.9833333333333334, u10 => 6.666666666666667, u11 => 6.666666666666667]
#  [u1 => 0.0, u2 => 0.0, u3 => -0.3, u4 => 0.0, u5 => -16.666666666666668, u6 => 0.0, u7 => 0.0, u8 => 26.666666666666668, u9 => 0.0, u10 => 0.7, u11 => 6.666666666666667]
#  [u1 => 0.0, u2 => -0.15, u3 => -0.15, u4 => 0.0, u5 => -16.666666666666668, u6 => 0.35, u7 => 16.666666666666668, u8 => 13.333333333333334, u9 => 0.35, u10 => 0.0, u11 => 3.3333333333333335]
#  [u1 => 0.0, u2 => -0.15, u3 => 0.0, u4 => -0.15, u5 => -16.666666666666668, u6 => 0.35, u7 => 16.666666666666668, u8 => 0.35, u9 => 16.666666666666668, u10 => 0.0, u11 => 0.0]
#  [u1 => -0.3, u2 => 0.0, u3 => 0.0, u4 => 0.0, u5 => -16.666666666666668, u6 => 26.666666666666668, u7 => 0.0, u8 => 0.0, u9 => 0.0, u10 => 6.666666666666667, u11 => 0.7]
#  [u1 => -0.15, u2 => 0.0, u3 => 0.0, u4 => -0.15, u5 => -16.666666666666668, u6 => 13.333333333333334, u7 => 0.35, u8 => 0.35, u9 => 16.666666666666668, u10 => 3.3333333333333335, u11 => 0.0]
#  [u1 => 0.0, u2 => -0.15, u3 => -0.3, u4 => 0.0, u5 => -8.333333333333334, u6 => 0.35, u7 => 8.333333333333334, u8 => 13.333333333333334, u9 => 0.0, u10 => 0.7, u11 => 3.3333333333333335]
#  [u1 => -0.3, u2 => 0.0, u3 => 0.0, u4 => -0.15, u5 => -8.333333333333334, u6 => 13.333333333333334, u7 => 0.0, u8 => 0.35, u9 => 8.333333333333334, u10 => 3.3333333333333335, u11 => 0.7]
#  [u1 => -0.15, u2 => 0.0, u3 => -0.15 + 0.4379334587419809im, u4 => 0.0, u5 => -1.75 - 5.10922368532311im, u6 => 1.4 + 4.087378948258489im, u7 => -2.9833333333333334, u8 => 13.333333333333334, u9 => 0.0, u10 => 0.7, u11 => 6.666666666666667]
#  [u1 => -0.15 + 0.4379334587419809im, u2 => 0.0, u3 => -0.15, u4 => 0.0, u5 => -1.75 - 5.10922368532311im, u6 => 13.333333333333334, u7 => 0.0, u8 => 1.4 + 4.087378948258489im, u9 => -2.9833333333333334, u10 => 6.666666666666667, u11 => 0.7]
#  [u1 => -0.15, u2 => 0.0, u3 => -0.15 - 0.4379334587419809im, u4 => 0.0, u5 => -1.75 + 5.10922368532311im, u6 => 1.4 - 4.087378948258489im, u7 => -2.9833333333333334, u8 => 13.333333333333334, u9 => 0.0, u10 => 0.7, u11 => 6.666666666666667]
#  ⋮
#  [u1 => 0.0, u2 => 0.0, u3 => 3.134413118755725, u4 => 2.7957823068761383, u5 => 0.41117099451457123, u6 => 0.0, u7 => 0.0, u8 => 0.35, u9 => 0.35, u10 => 0.0, u11 => 1.7183730123444139]
show(sssol)
# Out:
# [1.757923110083762, 1.402425241247472, 1.757923110083762, 1.402425241247472, 0.386357166944847, 0.35000011244227996, 0.28399314557178695, 0.35000011244227996, 0.28399314557178695, 0.1320139355150468, 0.1320139355150468]

# %% [markdown]
# ## Linear stability analysis

# %%
ks = LinRange(0., 20., 1000)
Ds = [fill(1e-4, 4); 0; fill(1, 4); fill(10, 2)]
usol = s.u[end]
#usol = sssol.u
#usol = Symbolics.value.(getindex.(symsol[2], 2))
show(uninplace(mmicrmfunc!)(usol, p.p, 0))
# Out:
# [-1.1819222299879754e-10, -6.082845444635082e-11, -1.1819222299879754e-10, -6.082845444635082e-11, 2.3157475936841365e-11, 1.3522072350724557e-11, 3.2949643014035246e-11, 1.3522072350724557e-11, 3.2949643014035246e-11, 1.2642054070255426e-11, 1.2642054070255426e-11]

# %%
lambdas = do_linstab_for_ks(ks, p, Ds, usol);
@show maximum(real(lambdas))
faa = plot_linstab_lambdas(ks, lambdas[:,:])
ylims!(faa.axis, (-0.5, 0.5))
#xlims!(faa.axis, (0., 2.))
faa
# Out:
# maximum(real(lambdas)) = 0.022845614207349447
# [ Info: we are getting non-zero imaginary parts, max(abs(.)) is 1.243212
# [ Info: we are getting non-zero imaginary parts, max(abs(.)) is 1.243212
# [ Info: we are getting non-zero imaginary parts, max(abs(.)) is 1.174344
# [ Info: we are getting non-zero imaginary parts, max(abs(.)) is 1.174344
# [ Info: we are getting non-zero imaginary parts, max(abs(.)) is 1.080949

# %%
# Finds the k with the biggest maximum eigenvalue
kmax_i = argmax(maximum.(eachrow(real(lambdas))))
kmax = ks[kmax_i]
kmax_i, kmax
# Out:
# (66, 1.3013013013013013)

# %%
ff = linstab_make_full_func(p.p, usol, Ds)
kmax_es = ff(kmax)
kmax_es.vectors[:,1] # the eigensystem is sorted by evalue so this is the one
# Out:
# 11-element Vector{Float64}:
#  -0.5424629824539051
#  -0.4534257277480289
#   0.5424629824539073
#   0.45342572774802803
#  -2.9106420734639386e-16
#  -0.003720543882350118
#  -0.0076385460517193245
#   0.00372054388235039
#   0.007638546051718841
#  -0.008175099437874268
#   0.008175099437873909

# %% [markdown]
# ## Spatial stuff - 1D!

# %%
ssize = (1000,)
su0 = expand_u0_to_size(ssize, usol)
psu0 = perturb_u0_uniform(get_Ns(p.p)..., su0, 0.1, 0.1)
space = make_cartesianspace_smart(length(ssize); dx=0.04, bcs=Periodic())
usenthreads = prod(ssize) >= 100 ? nthreads() : nothing
sp = make_smmicrm_problem_safe(
    psu0, 100000, p.p, SA[Ds...], space, usenthreads;
)
size(sp.u0), sp.p.usenthreads, sp.p.space
# Out:
# ((11, 1000), 18, CartesianSpace{1, Tuple{Periodic}, Float64}([0.04]))

# %% [markdown]
# #### Direct solver

# %%
@time sps = solve(sp, QNDF(); maxiters=1000)
display(sps.retcode)
display(sps.destats.nf)
#display(plot_1dsmmicrm_sol_snap(sps.prob.p, sps.u[end-1]))
plot_1dsmmicrm_sol_snap(sps.prob.p, sps.u[end])
# Out:
#  14.785184 seconds (1.04 M allocations: 4.190 GiB, 19.50% gc time)
# ReturnCode.Success = 1
# 6603

# %% [markdown]
# #### Steady state solver

# %%
sssp = SteadyStateProblem(sp)
@time sssps = solve(sssp, DynamicSS(QNDF()); maxiters=1000)
display(sssps.retcode)
display(sssps.original.destats.nf)
plot_1dsmmicrm_sol_snap(sssps.prob.p, sssps.u)
# Out:
#  12.204321 seconds (836.84 k allocations: 2.199 GiB, 1.90% gc time)
# ReturnCode.Success = 1
# 2803

# %% [markdown]
# ## Spatial stuff - 2D!

# %%
ssize = (80,80)
su0 = expand_u0_to_size(ssize, usol)
psu0 = perturb_u0_uniform(get_Ns(p.p)..., su0, 1e-6)
space = make_cartesianspace_smart(length(ssize); dx=0.1, bcs=Periodic())
usenthreads = prod(ssize) >= 100 ? nthreads() : nothing
sp = make_smmicrm_problem_safe(
    psu0, 100000000, p.p, SA[Ds...], space, usenthreads;
)
size(sp.u0), sp.p.usenthreads, sp.p.space
# Out:
# ((11, 80, 80), 18, CartesianSpace{2, Tuple{Periodic, Periodic}, Float64}([0.1, 0.1]))

# %% [markdown]
# #### Direct solver

# %%
@time sps = solve(sp, TRBDF2(); maxiters=1000)
display(sps.retcode)
display(sps.destats.nf)
@show length(sps.u)
#display(plot_1dsmmicrm_sol_snap(sps.prob.p, sps.u[end-1]))
#plot_1dsmmicrm_sol_snap(sps.prob.p, sps.u[end])
# Out:
# 797.800366 seconds (2.31 M allocations: 251.387 GiB, 1.54% gc time)
# ReturnCode.Success = 1
# 6688

# %%
sps = load_object("../data/layers47/sol2d1.jld2");
@show length(sps.u)
# Out:
# length(sps.u) = 684
# 684

# %%
heatmap(sps(2000)[1,:,:])

# %%
plot_smmicrm_sol_avgs(sps, 1:200; plote=true)

# %%
sps.stats
# Out:
# SciMLBase.DEStats
# Number of function 1 evaluations:                  6688
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    370
# Number of linear solves:                           5575
# Number of Jacobians created:                       57
# Number of nonlinear solver iterations:             4306
# Number of nonlinear solver convergence failures:   0
# Number of fixed-point solver iterations:                     0
# Number of fixed-point solver convergence failures:           0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          683
# Number of rejected steps:                          88

# %%
save_object(datadir("layers47", randname()*".jld2"), sps)

# %% [markdown]
# #### Loading/saving solutions

# %% [markdown]
# #### Extra time

# %%
ftime = sps.prob.tspan[end]
esp = remake(sps.prob; u0=sps.u[end], tspan=(ftime, 2*ftime));
size(esp.u0), esp.p.usenthreads, esp.p.space
# Out:
# ((11, 80, 80), 18, CartesianSpace{2, Tuple{Periodic, Periodic}, Float64}([0.1, 0.1]))

# %%
@time sps = solve(esp, TRBDF2(); maxiters=1000)
display(sps.retcode)
display(sps.destats.nf)
# Out:
#  85.280936 seconds (1.28 M allocations: 13.719 GiB, 5.73% gc time)
# ReturnCode.Success = 1
# 103

# %%
heatmap(sps.u[end][8,:,:])

# %%
plot_smmicrm_sol_avgs(sps; plote=true)

# %% [markdown]
# # Extras

# %%
GC.gc()
empty!(Out)
# Out:
# Dict{Int64, Any}()
