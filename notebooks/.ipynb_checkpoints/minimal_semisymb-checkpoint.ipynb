# %%
using Revise
using SSMCMain, SSMCMain.MinimalModelSemisymbolic
using CairoMakie
using Symbolics
import Nemo
using JLD2
using Base.Threads
# Out:
# Precompiling packages...
#   29259.7 ms  ✓ SSMCMain
#   1 dependency successfully precompiled in 35 seconds. 480 already precompiled.
# Welcome to Nemo version 0.48.4
#
# Nemo comes with absolutely no warranty whatsoever

# %%
using GLMakie
CairoMakie.activate!()
# display(GLMakie.Screen(), f.figure)

# %% [markdown]
# # Loading pscan data

# %%
data = jldopen("../data/minimalmodel/smallscan6.jld2");
ns_params = [data[x] for x in ["m", "l", "K", "c", "d"]];
Ds_params = [data[x] for x in ["DN", "DG", "DR"]];
ns_i_to_params = ci -> getindex.(ns_params, ci.I);
Ds_i_to_params = ci -> getindex.(Ds_params, ci.I);
num_sss = data["num_ns_steadystates"]
num_modes = data["total_num_modes"];
sss = data["ns_steadystates"];
num_modes_secs = (data["num_modes_secs"]);

# %%
pcis = CartesianIndices(num_sss)
Dcis =  CartesianIndices(size(num_modes)[end-2:end])
fi_to_nsps = fci -> getindex.(ns_params, fci.I[1:5])
fi_to_Ds = fci -> getindex.(Ds_params, fci.I[6:8])
fi_to_fparams = fci -> vcat(fi_to_nsps(fci), fi_to_Ds(fci));

# %% [markdown]
# ## Finding conditions for instabilities

# %%
@show unique(num_modes)
fcis_unstable = findall(x->x!=0, num_modes);
length(fcis_unstable) / length(num_modes)
# Out:
# unique(num_modes) = [0, 1]
# 0.026856733920134126

# %%
fi_to_run = fcis_unstable[1]
# Out:
# CartesianIndex(6, 6, 2, 2, 2, 1, 2, 1)

# %%
ll = filter(x->x.I[2]==6, fcis_unstable);

# %%
xs = [ci.I[1] for ci in ll]
ys = [ci.I[7] for ci in ll]
zs = [ci.I[6] for ci in ll]
display(GLMakie.Screen(), scatter(xs, ys, zs))
# Out:
# GLMakie.Screen(...)

# %% [markdown]
# ## Do we get unstable states in extinct only systems?

# %%
extinct_trh = 2*eps()
pcis_extinct_only = []
pcis_nextinct_only = []
for pci in pcis
    if num_sss[pci] == 1
        ss = sss[pci][1]
        if ss[1] < extinct_trh
            push!(pcis_extinct_only, pci)
        else
            push!(pcis_nextinct_only, pci)
        end
    end
end
display(length(pcis_extinct_only) / length(num_sss))
display(length(pcis_nextinct_only) / length(num_sss))
# Out:
# 0.28022119341563784
# 0.6180555555555556

# %%
count(pci->maximum(num_modes[pci,:,:,:])!=0, pcis_extinct_only)
# Out:
# 0

# %%
extinct_trh = 2*eps()
for pci in pcis
    for (ss_i, ss) in enumerate(sss[pci])
        if ss[1] < extinct_trh
            for Dci in Dcis
                nms = num_modes_secs[pci, Dci][ss_i]
                tnmss = sum(nms)
                @show nms
                if tnmss != 0
                    @show ss tnmss
                end
            end
        end
    end
end
# Out:
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# ...
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0, 0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0, 0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms =
# Excessive output truncated after 524293 bytes.
# [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]
# nms = [0]

# %%
argmax(num_modes)
# Out:
# CartesianIndex(6, 6, 2, 2, 2, 1, 2, 1)

# %% [markdown]
# # Inspecting a single system

# %%
# mmpf = MinimalModelParamsSpace(0.1, 0., 10., 0.01, 0.01, 1e-5, 0.01584893192461114, 0.00039810717055349735);
mmpf = MinimalModelParamsSpace(fi_to_fparams(fi_to_run)...)
mmicrm_params = mmp_to_mmicrm(mmpf);
mmpf
# Out:
# MinimalModelParamsSpace{Float64}(2.0, 1.0, 2.08, 4.008, 4.008, 1.0e-5, 0.00039810717055349735, 1.0e-5)

# %%
xx = analyze_single_mmps(mmpf; include_extinct=true)
# Out:
# (2, 1, [[0.374992839497788, 0.8310123249964403, 0.4990019960079839], [0.0, 2.08, 0.0]], [[60.142249400554505, 235.37689849412098], Float64[]], [[0, 1, 0], [0]])

# %% [markdown]
# ## Numerics

# %%
all_sols = solve_nospace(mmpf)
p_sols = all_sols[nospace_sol_check_physical.(all_sols)]
display(p_sols)
nospace_sol_check_stable.(Ref(mmpf), p_sols)
# Out:
# 3-element Vector{Vector{Float64}}:
#  [0.374992839497788, 0.8310123249964403, 0.4990019960079839]
#  [0.16600516449422828, 1.2489876750035596, 0.4990019960079839]
#  [0.0, 2.08, 0.0]
# 3-element BitVector:
#  1
#  0
#  1

# %%
nssol = p_sols[1]
# Out:
# 3-element Vector{Float64}:
#  0.374992839497788
#  0.8310123249964403
#  0.4990019960079839

# %% [markdown]
# #### Linstab

# %%
ks = LinRange(0., 400, 10000)
Ds = collect(get_Ds(mmpf))

lambdas = do_linstab_for_ks(ks, mmicrm_params, Ds, nssol);
mrl = maximum(real(lambdas))
@show mrl
faa = plot_linstab_lambdas(ks, lambdas)
ylims!(faa.axis, (-8*mrl, 2*mrl))
# xlims!(faa.axis, (0., 2.))
#display(GLMakie.Screen(), faa.figure)
faa
# Out:
# mrl = 0.24450394343745338
# [ Info: we are getting non-zero imaginary parts, max(abs(.)) is 0.643883
# [ Info: we are getting non-zero imaginary parts, max(abs(.)) is 0.643883

# %%
# Finds the k with the biggest maximum eigenvalue
kmax_i = argmax(maximum.(eachrow(real(lambdas))))
kmax = ks[kmax_i]
kmax_i, kmax
ff = linstab_make_full_func(p.p, usol, Ds)
kmax_es = ff(kmax)
kmax_es.vectors[:,1] # the eigensystem is sorted by evalue so this is the one
# Out:
# 3-element Vector{Float64}:
#  -0.9999951691507666
#   0.00225760675149163
#   0.002136559590917483

# %% [markdown]
# ### 1D PDE sim

# %%
ssize = (4000,)
su0 = expand_u0_to_size(ssize, nssol)
psu0 = perturb_u0_uniform(get_Ns(mmicrm_params)..., su0, 0.1, 0.1)
space = make_cartesianspace_smart(length(ssize); dx=0.0001, bcs=Periodic())
usenthreads = prod(ssize) >= 100 ? nthreads() : nothing
sp = make_smmicrm_problem_safe(
    psu0, 1e6, mmicrm_params, get_Ds(mmpf), space, usenthreads;
)
size(sp.u0), sp.p.usenthreads, sp.p.space
# Out:
# ((3, 4000), 18, CartesianSpace{1, Tuple{Periodic}, Float64}([0.0001]))

# %%
@time sps = solve(sp, QNDF(); maxiters=1000)
print_spatial_solution_stats(sps)
# Out:
#   1.847934 seconds (269.41 k allocations: 683.504 MiB, 12.53% gc time)
# Success
# nf is 627
# solution has 140 saved states
# max resid is 4.52497e-10

# %%
plot_1dsmmicrm_sol_snap(sps.prob.p, sps(sps.t[end]))

# %%
f = plot_smmicrm_sol_avgs(sps, 1:35)
# display(GLMakie.Screen(), f)

# %% [markdown]
# # Bits and bobs

# %% [markdown]
# ### Testing

# %%
xx = solve_nospace(mmpf)
# Out:
# 3-element Vector{Vector{Float64}}:
#  [18.986832980505135, 0.05131670194948621, 0.05000000000000001]
#  [0.013167019494861876, 1.9486832980505142, 0.04999999999999954]
#  [0.0, 2.0, 0.0]

# %%
M1 = make_M1(mmicrm_params, xx[1])
# Out:
# 3×3 Matrix{Float64}:
#   1.38778e-17    0.0      37.9737
#  -0.102633     -38.9737    0.0
#   0.0026334     37.9737  -38.9737

# %%
pol = make_K_polynomial(M1, get_Ds(mmpf))
# Out:
# 4-element SVector{4, Float64} with indices SOneTo(4):
#    -0.0005
#    -0.19490730347101168
#    49.98481053361589
#  -144.099930651839

# %%
fks = LinRange(0, 200, 10000)
yy = eval_cubic.(Ref(pol), fks)
lines(sqrt.(fks), yy)

# %% [markdown]
# ### Finding params so that D=0

# %%
@variables a b c d x p q t;
sx = t - 3*b / a
st = x + 3*b / a
display(sx)
display(st)
# Out:
# t + (-3b) / a
# x + (3b) / a

# %%
ep = (3*a*c - b^2) / (3*a^2)
eq = (2*b^3 - 9*a*b*c + 27*a^2*d) / (27*a^3)
display(ep)
display(eq)
# Out:
# (3a*c - (b^2)) / (3(a^2))
# (27(a^2)*d - 9a*b*c + 2(b^3)) / (27(a^3))

# %%
eD = q^2/4 + p^3/27
display(eD)
# Out:
# (1//4)*(q^2) + (1//27)*(p^3)

# %%
fD = simplify(substitute(substitute(eD, p=>ep), q=>eq))
# Out:
# ((27//1)*(a^2)*(d^2) - (18//1)*a*b*c*d + (4//1)*a*(c^3) + (4//1)*(b^3)*d - (b^2)*(c^2)) / (108(a^4))

# %%
D0_sd = simplify(symbolic_solve(fD~0, d))
# Out:
# 2-element Vector{SymbolicUtils.BasicSymbolic{Real}}:
#  (√(-432(a^3)*(c^3) + 432(a^2)*(b^2)*(c^2) - 144a*(b^4)*c + 16(b^6)) + 18a*b*c - 4(b^3)) / (54(a^2))
#  (-√(-432(a^3)*(c^3) + 432(a^2)*(b^2)*(c^2) - 144a*(b^4)*c + 16(b^6)) + 18a*b*c - 4(b^3)) / (54(a^2))

# %%
simplify(substitute(D0_sd[1], [a=>1,b=>1,c=>0.1]))
# Out:
# 0.002641631005470585571790650969636567983439420046482461039933878046183213123669783
