# %%
include("../runs/mm_maybemoving_extra/base.jl")
# Out:
# Precompiling packages...
#    1166.4 ms  ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#    1369.3 ms  ✓ IntervalSets → IntervalSetsRecipesBaseExt
#    1155.6 ms  ✓ IntervalArithmetic → IntervalArithmeticRecipesBaseExt
#    1336.1 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsStructArraysExt
#    1973.6 ms  ✓ IntervalArithmetic → IntervalArithmeticForwardDiffExt
#    2016.0 ms  ✓ SciMLBase → SciMLBaseChainRulesCoreExt
# ┌ Warning: attempting to remove probably stale pidfile
# │   path = "/home/xucapjko/.julia/compiled/v1.10/LinearSolve/WR6RC_7qZ70.ji.pidfile"
# └ @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.9+0.x64.linux.gnu/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:244
#    2767.2 ms  ✓ LineSearch → LineSearchLineSearchesExt
#    2341.4 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseMatrixColoringsExt
#    2793.0 ms  ✓ OptimizationBase
#    2339.4 ms  ✓ DiffEqBase → DiffEqBaseUnitfulExt
# ...

# %%
using CairoMakie
# Out:
# Precompiling packages...
#   29602.5 ms  ✓ CairoMakie
#   1 dependency successfully precompiled in 35 seconds. 241 already precompiled.
# [ Info: Precompiling CairoMakie [13f3f980-e62b-5c42-98c6-ff1f3baf88f0]

# %%
@show 42
# Out:
# 42 = 42
# 42
