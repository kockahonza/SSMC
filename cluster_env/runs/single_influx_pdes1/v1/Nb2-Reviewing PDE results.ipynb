# %%
]activate ../../../
# Out:
#   Activating project at `~/UCLOneDrive/SpatialStructureInMicrobialCommunities/SSMCCode`

# %%
using Revise
includet("./base.jl")

# %%
using GLMakie
using CairoMakie
CairoMakie.activate!()

# %%
import DataFrames: metadata as md

# %% [markdown]
# # Setup

# %%
function plot_spatial_fs(u, Ns, sN, dx;
    figure=(;),
    axis=(;),
)
    Nr = size(u)[1] - Ns
    xs = ((1:sN) .- 0.5) .* dx
    
    fig = Figure(; figure...)
    axs = Axis(fig[1,1]; axis...)
    axr = Axis(fig[2,1]; axis...)
    linkxaxes!(axs, axr)
    hidexdecorations!(axs)
    rowgap!(fig.layout, 2.)

    for i in 1:Ns
        lines!(axs, xs, u[i,:])
    end
    for a in 1:Nr
        lines!(axr, xs, u[Ns+a,:])
    end

    fig
end
# f = plot_spatial_fs(xx.final_states[4], N, dx)
# display(GLMakie.Screen(), f)
# f
# Out:
# plot_spatial_fs (generic function with 1 method)

# %% [markdown]
# # Run 1/2 - both rslt_df1 and rslt_df2
# - N=M=20
# - pe=pei=0.15 <=> B = 3
# - Ds are 1e-6, 1., 1.
# - slightly varied lognormal m
# - L=5 with 5000 grid points

# %%
f = jldopen("./rslt_df1.jld2")
f2 = jldopen("./rslt_df2.jld2")
df = vcat(f["df"], f2["df"])
close(f)
close(f2)

N = md(df, "N")
M = md(df, "M")
sN = md(df, "sN")
dx = md(df, "dx")

@printf "There are %d runs out of %d that did not finish at T\n" count(!=(md(df, "T")), df.final_Ts) nrow(df)
@show N, M;
# Out:
# There are 1 runs out of 26 that did not finish at T
# (N, M) = (20, 20)

# %%
sr = rand(eachrow(df));

# %%
ps = sr.params
ss = sr.steadystates;
cmin = max(minimum(abs, ss), eps())
css = clamp.(ss, cmin, Inf);

# %% [markdown]
# ### Spatial final state

# %%
plot_spatial_fs(sr.final_states, N, sN, dx;
    figure=(; size=(1000, 400))
)

# %% [markdown]
# ### No-space ss and network structure

# %%
scatter(css[1:N], fill(1, N);
    figure=(; size=(800, 100)),
    axis=(;
        xscale=log10,
        yticks=([], [])
    )
)

# %%
diagram_sfss_v3(sr.params, sr.steadystates;
    strain_threshold=1e-2,
    # colorscale=log10,
)
# Out:
# digraph {
#   graph[rankdir="LR";];
#   "chemostat"[label="chemostat";shape="rect";];
#   "N1"[color="#4BC26D";label="N_1
# 2.95";shape="ellipse";];
#   "N3"[color="#56C666";label="N_3
# 3.04";shape="ellipse";];
#   "N11"[color="#A6DB35";label="N_11
# 3.58";shape="ellipse";];
#   "R8"[color="#3C508B";label="R_8
# 0.999";shape="rect";];
#   "R3"[color="#440154";label="R_3
# 5.89e-32";shape="rect";];
#   "R14"[color="#FDE725";label="R_14
# 4.13";shape="rect";];
#   "R16"[color="#3C508B";label="R_16
# 0.996";shape="rect";];
#   "R2"[color="#3C508B";label="R_2
# 0.999";shape="rect";];
#   "R8"->"N1"[color="#433D84";label="2.95";];
#   "N3"->"R8"[color="#3C4E8A";label="3.95";];
#   "R3"->"N3"[color="#440154";label="1.79e-31";];
#   "R14"->"N3"[color="#5EC962";label="12.6";];
#   "R16"->"N3"[color="#433E85";label="3.03";];
#   "N3"->"R16"[color="#3C508B";label="4.03";];
#   "N3"->"R2"[color="#38598C";label="4.58";];
#   "R2"->"N11"[color="#3F4889";label="3.58";];
#   "chemostat"->"R14"[color="#FDE725";label="16.7";];
# }

# %% [markdown]
# ### Linstab

# %%
k_to_evals = linstab_make_k_func(ps, ss)
# ks = 10 .^ range(-5, 3, 100)
ks = range(0.001, 50, 1000)
@time evals = k_to_evals.(ks);
# Out:
#   0.393469 seconds (368.55 k allocations: 59.612 MiB, 8.46% gc time, 94.23% compilation time)

# %%
faa = plot_linstab_lambdas(ks, evals;
    axis=(;
        # xscale=log10
    ),
    legend=false
)

# display(GLMakie.Screen(), faa.figure)
faa
# Out:
# [ Info: Unstable, mrl is 0.0202128

# %% [markdown]
# # Run 3 - rslt_df3 (N=M=50, otherwise same as Runs 1/2)
# - N=M=50
# - pe=pei=0.06 <=> B = 3
# - Ds are 1e-6, 1., 1.
# - slightly varied lognormal m
# - L=5 with 5000 grid points

# %%
f = jldopen("./rslt_df3.jld2")
df = copy(f["df"])
close(f)

N = md(df, "N")
M = md(df, "M")
sN = md(df, "sN")
dx = md(df, "dx")

@printf "There are %d runs out of %d that did not finish at T\n" count(!=(md(df, "T")), df.final_Ts) nrow(df)
@show N, M;
# Out:
# There are 0 runs out of 6 that did not finish at T
# (N, M) = (50, 50)

# %%
df.numsurv
# Out:
# 6-element Vector{Int64}:
#  2
#  3
#  4
#  5
#  3
#  8

# %%
sr = rand(eachrow(df));
sr = df[3,:];

# %%
ps = sr.params
ss = sr.steadystates;
cmin = max(minimum(abs, ss), eps())
css = clamp.(ss, cmin, Inf);

# %% [markdown]
# ### Spatial final state

# %%
plot_spatial_fs(sr.final_states, N, sN, dx;
    figure=(; size=(1000, 400))
)

# %% [markdown]
# ### No-space ss and network structure

# %%
scatter(css[1:N], fill(1, N);
    figure=(; size=(800, 100)),
    axis=(;
        xscale=log10,
        yticks=([], [])
    )
)

# %%
# diagram_sfss_v3(sr.params, fill(1., N+M);
diagram_sfss_v3(sr.params, sr.steadystates;
    strain_threshold=1e-2,
    edge_threshold=1e-5,
    # colorscale=log10,
)
# Out:
# digraph {
#   graph[rankdir="LR";];
#   "chemostat"[label="chemostat";shape="rect";];
#   "N5"[color="#FDE725";label="N_5
# 6.83";shape="ellipse";];
#   "N6"[color="#B5DE2B";label="N_6
# 6.08";shape="ellipse";];
#   "N8"[color="#38588C";label="N_8
# 1.87";shape="ellipse";];
#   "N11"[color="#23A983";label="N_11
# 4.13";shape="ellipse";];
#   "N16"[color="#2D708E";label="N_16
# 2.51";shape="ellipse";];
#   "R9"[color="#2C738E";label="R_9
# 2.58";shape="rect";];
#   "R11"[color="#440154";label="R_11
# 0.0098";shape="rect";];
#   "R13"[color="#46337F";label="R_13
# 0.992";shape="rect";];
#   "R17"[color="#46327F";label="R_17
# 0.988";shape="rect";];
#   "R2"[color="#46337F";label="R_2
# 1";shape="rect";];
#   "R10"[color="#46337F";label="R_10
# 0.996";shape="rect";];
#   "R5"[color="#46337F";label="R_5
# 1";shape="rect";];
#   "R9"->"N5"[color="#218E8D";label="17.6";];
#   "R11"->"N5"[color="#440255";label="0.0669";];
#   "R13"->"N5"[color="#424086";label="6.77";];
#   "N5"->"R13"[color="#3F4889";label="7.77";];
#   "N5"->"R17"[color="#414287";label="7";];
#   "N5"->"R2"[color="#481E70";label="2.88";];
#   "R9"->"N6"[color="#26818E";label="15.7";];
#   "R11"->"N6"[color="#440255";label="0.0596";];
#   "N6"->"R11"[color="#440255";label="0.136";];
#   "R17"->"N6"[color="#443A83";label="6.01";];
#   "N6"->"R10"[color="#46327F";label="5.11";];
#   "N6"->"R5"[color="#482475";label="3.51";];
#   "R2"->"N8"[color="#481567";label="1.88";];
#   "R10"->"N11"[color="#482979";label="4.11";];
#   "R5"->"N16"[color="#481B6D";label="2.51";];
#   "chemostat"->"R9"[color="#FDE725";label="35.9";];
# }

# %% [markdown]
# ### Linstab

# %%
k_to_evals = linstab_make_k_func(ps, ss)
# ks = 10 .^ range(-5, 3, 100)
ks = range(0.001, 50, 1000)
@time evals = k_to_evals.(ks);
# Out:
#   0.158278 seconds (12.00 k allocations: 40.062 MiB)

# %%
faa = plot_linstab_lambdas(ks, evals;
    axis=(;
        # xscale=log10
    ),
    legend=false
)

# display(GLMakie.Screen(), faa.figure)
faa
# Out:
# [ Info: Unstable, mrl is 0.00351939
