# %%
include("base.jl")
# Out:
# [ Info: Precompiling SSMCMain [a75ad852-21c5-4a12-a12f-b1392bb0ea4b]
# job1 (generic function with 1 method)

# %%
using CairoMakie
# Out:
# Precompiling packages...
#   24533.8 ms  ✓ CairoMakie
#   1 dependency successfully precompiled in 26 seconds. 241 already precompiled.

# %% [markdown]
# # No perturbation

# %%
nop_sps = load_object("nop_sol.jld2")
# Out:
# retcode: Success
# Interpolation: 3rd order Hermite
# t: 412-element Vector{Float64}:
#  7.518266985339596e6
#  7.518266985339597e6
#  7.518266985339606e6
#  7.518266985339699e6
#  7.518266985340631e6
#  7.518266985346655e6
#  7.518266985357607e6
#  7.518266985380473e6
#  7.518266985435088e6
#  7.518266985554004e6
#  7.518266985797612e6
#  7.518266986295513e6
#  7.518266987280328e6
#  ⋮
#  9.283277187760236e6
#  9.323950066457717e6
#  9.395849636202365e6
#  9.467749205947014e6
#  9.597138913602414e6
#  9.726528621257814e6
#  9.855918328913214e6
#  1.03396533511449e7
#  1.1287177605802529e7
#  1.6034795431131098e7
#  3.545957887398137e7
#  8.270093683873555e7
# u: 412-element Vector{Array{Float64, 3}}:
# ...

# %%
nop_sps.t

# %%
f = plot_2dsmmicrm_sol_snap_heatmap(nop_sps, -1)

# %%
p5_sps = load_object("p5_sol.jld2")
