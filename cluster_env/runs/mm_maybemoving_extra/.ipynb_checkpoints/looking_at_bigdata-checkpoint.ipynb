# %%
include("base.jl")
# Out:
# [ Info: Precompiling SSMCMain [a75ad852-21c5-4a12-a12f-b1392bb0ea4b]
# ┌ Warning: attempting to remove probably stale pidfile
# │   path = "/home/xucapjko/.julia/compiled/v1.10/LazyArrays/h0pkJ_7qZ70.ji.pidfile"
# └ @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.9+0.x64.linux.gnu/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:244
# ┌ Warning: attempting to remove probably stale pidfile
# │   path = "/home/xucapjko/.julia/compiled/v1.10/ArrayLayouts/QloHc_7qZ70.ji.pidfile"
# └ @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.9+0.x64.linux.gnu/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:244
#
# [121114] signal (2): Interrupt
# in expression starting at /home/xucapjko/.julia/packages/OrdinaryDiffEqNonlinearSolve/e4hoO/src/OrdinaryDiffEqNonlinearSolve.jl:14
#
# [115166] signal (2): Interrupt
# in expression starting at /home/xucapjko/SSMC/src/SSMCMain/src/SSMCMain.jl:6
# epoll_wait at /lib64/libc.so.6 (unknown line)
#
# [115169] signal (2): Interrupt
# ...

# %%
using CairoMakie

# %%
@show 42
